# %% [markdown]
# ### What is histplot()?
# - It is used to create univariate (or) bivariate histograms that visualize the distribution of datasets by counting observations within discrete bins.
# - Syntax - sns.histplot(data, x=None, y=None, hue=None, weights=None, stat='count', bins='auto', binwidth=None, binrange=None, discrete=None, cumulative=False, common_bins=True, common_norm=True, multiple='layer', element='bars', fill=True, shrink=1, kde=False, kde_kws=None, palette=None, hue_order=None, hue_norm=None, color=None, log_scale=None, legend=True, ax=None, **kwargs)

# %% [markdown]
# ### Imported required libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statistics as sts

# %%
pd.set_option('display.max_rows',None)

# %% [markdown]
# ### Import Dataset

# %%
mart = pd.read_excel(r"supermarket_sales.xlsx")
mart = mart[['Gender','Payment','Unit price','Quantity','Total','gross income']]
mart.head(10)
# Out:
#    Gender      Payment  Unit price  Quantity     Total  gross income
# 0  Female  Credit card       54.84         3  172.7460        8.2260
# 1  Female      Ewallet       14.48         4   60.8160        2.8960
# 2    Male         Cash       25.51         4  107.1420        5.1020
# 3  Female         Cash       93.72         6  590.4360       28.1160
# 4  Female      Ewallet       40.30         2   84.6300        4.0300
# 5    Male      Ewallet       87.98         3  277.1370       13.1970
# 6    Male  Credit card       33.20         2   69.7200        3.3200
# 7    Male         Cash       33.52         1   35.1960        1.6760
# 8  Female         Cash       88.36         5  463.8900       22.0900
# 9    Male  Credit card       94.13         5  494.1825       23.5325

# %% [markdown]
# ### 1. Create a basic HISTOGRAM on X or Y axis

# %%
sns.histplot(data=mart, y='Total')
# Out:
# <Axes: xlabel='Count', ylabel='Total'>

# %% [markdown]
# ### 2. Change the Bins Width using binwidth arguement

# %%
sns.histplot(data=mart, x='Total', binwidth=150)
# Out:
# <Axes: xlabel='Total', ylabel='Count'>

# %% [markdown]
# ### 3. Change Number of Bins and Interval

# %%
plt.figure(figsize=(15,5))
sns.histplot(data=mart, x='Total', bins=np.arange(0,1100,50))
plt.xticks(np.arange(0,1100,50))
# Out:
# ([<matplotlib.axis.XTick at 0x2002c8e9310>,
#   <matplotlib.axis.XTick at 0x2002c9211d0>,
#   <matplotlib.axis.XTick at 0x2002c921950>,
#   <matplotlib.axis.XTick at 0x2002c9220d0>,
#   <matplotlib.axis.XTick at 0x2002c922850>,
#   <matplotlib.axis.XTick at 0x2002c922fd0>,
#   <matplotlib.axis.XTick at 0x2002c923750>,
#   <matplotlib.axis.XTick at 0x2002c1cafd0>,
#   <matplotlib.axis.XTick at 0x2002c8eb610>,
#   <matplotlib.axis.XTick at 0x2002c07bc50>,
#   <matplotlib.axis.XTick at 0x2002c910410>,
#   <matplotlib.axis.XTick at 0x2002c910b90>,
#   <matplotlib.axis.XTick at 0x2002c911310>,
#   <matplotlib.axis.XTick at 0x2002c911a90>,
#   <matplotlib.axis.XTick at 0x2002c912210>,
#   <matplotlib.axis.XTick at 0x2002c912990>,
#   <matplotlib.axis.XTick at 0x2002c913110>,
#   <matplotlib.axis.XTick at 0x2002c913890>,
#   <matplotlib.axis.XTick at 0x2002c0b8050>,
#   <matplotlib.axis.XTick at 0x2002c0b87d0>,
#   <matplotlib.axis.XTick at 0x2002c0b8f50>,
#   <matplotlib.axis.XTick at 0x2002c0b96d0>],
#  [Text(0, 0, '0'),
#   Text(50, 0, '50'),
#   Text(100, 0, '100'),
#   Text(150, 0, '150'),
#   Text(200, 0, '200'),
#   Text(250, 0, '250'),
#   Text(300, 0, '300'),
#   Text(350, 0, '350'),
#   Text(400, 0, '400'),
#   Text(450, 0, '450'),
#   Text(500, 0, '500'),
#   Text(550, 0, '550'),
#   Text(600, 0, '600'),
#   Text(650, 0, '650'),
#   Text(700, 0, '700'),
#   Text(750, 0, '750'),
#   Text(800, 0, '800'),
#   Text(850, 0, '850'),
#   Text(900, 0, '900'),
#   Text(950, 0, '950'),
#   Text(1000, 0, '1000'),
#   Text(1050, 0, '1050')])

# %% [markdown]
# ### 4. Combine with KDE

# %%
sns.histplot(data=mart, x='Total', kde=True)
# Out:
# <Axes: xlabel='Total', ylabel='Count'>

# %% [markdown]
# ### 5. Use a categorical variable in HUE and STACK it using MULTIPLE agruement

# %%
sns.histplot(data=mart,x='Total',hue='Payment',multiple='stack')
# Out:
# <Axes: xlabel='Total', ylabel='Count'>

# %% [markdown]
# ### 6. Make it a step/poly plot using ELEMENT arguement and change the FILL

# %%
sns.histplot(data=mart,x='Total',hue='Payment',element='poly')
# Out:
# <Axes: xlabel='Total', ylabel='Count'>

# %% [markdown]
# ### 7. Use categorical variable and shrink it

# %%
sns.histplot(data=mart,x='Total',stat='probability')
# Out:
# <Axes: xlabel='Total', ylabel='Probability'>

# %% [markdown]
# ### 8. Create a Bivariate Histogram

# %%
sns.histplot(data=mart,x='Total',y='gross income')
