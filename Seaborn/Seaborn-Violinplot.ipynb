# %% [markdown]
# ### What is Violinplot?
# - This function draws a combination of a blox plot and KDE(Kernel density estimate) to visualize the distribution of data across categorical variables.
# - Syntax - sns.violinplot(data=None, *, x=None, y=None, hue=None, order=None, hue_order=None, orient=None, color=None, palette=None, saturation=0.75, fill=True, inner='box', split=False, width=0.8, dodge='auto', gap=0, linwidth=None, linecolor='auto', cut=2, gridsize=100, bw_method='scott', bw_adjust=1, density_norm='area', common_norm=False, hue_norm=None, formatter=None, kog_scale=None, native_scale=False, legend='auto', scale=<deprecated>, scale_hue=<deprecated>, inner_kws=None, ax=None, **kwargs)

# %% [markdown]
# ### Import all the required libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Import DataFrame

# %%
mart = pd.read_excel('supermarket_sales.xlsx')
mart.head()
# Out:
#     Invoice ID Branch      City Customer type  Gender            Product line  \
# 0  692-92-5582      B  Mandalay        Member  Female      Food_and_beverages
# 1  351-62-0822      B  Mandalay        Member  Female     Fashion_accessories
# 2  529-56-3974      B  Mandalay        Member    Male  Electronic_accessories
# 3  299-46-1805      B  Mandalay        Member  Female       Sports_and_travel
# 4  319-50-3348      B  Mandalay        Normal  Female      Home_and_lifestyle
#
#    Unit price  Quantity  Tax 5%    Total                 Date      Time  \
# 0       54.84         3   8.226  172.746            2/20/2019  13:27:00
# 1       14.48         4   2.896   60.816  2019-06-02 00:00:00  18:07:00
# 2       25.51         4   5.102  107.142  2019-09-03 00:00:00  17:03:00
# 3       93.72         6  28.116  590.436            1/15/2019  16:19:00
# 4       40.30         2   4.030   84.630  2019-11-03 00:00:00  15:30:00
#
# ...

# %% [markdown]
# ### Create a basic VIOLINPLOT

# %%
sns.violinplot(y="Total", data=mart)
# Out:
# <Axes: ylabel='Total'>

# %% [markdown]
# ### Create a VIOLINPLOT on two categorical and one numeric variable and use split

# %%
sns.violinplot(x='Payment', y='Total', hue='Gender', data=mart, split=True)
# Out:
# <Axes: xlabel='Payment', ylabel='Total'>

# %% [markdown]
# ### Change the box in the VIOLINPLOT to horzontal lines

# %%
sns.violinplot(x='Payment', y='Total', hue='Gender', data=mart, split=True, inner='quartile')
# Out:
# <Axes: xlabel='Payment', ylabel='Total'>

# %% [markdown]
# ### Draw line for each observations in a VIOLINPLOT

# %%
sns.violinplot(x='Payment', y='Total', hue='Gender', data=mart, split=True, inner='stick')
# Out:
# <Axes: xlabel='Payment', ylabel='Total'>

# %% [markdown]
# ### Change the amount of smoothing using bw attribute

# %%
sns.violinplot(x='Payment',y='Total',hue='Gender',data=mart,split=True,inner='quartile',bw_method=0.2)
# Out:
# <Axes: xlabel='Payment', ylabel='Total'>

# %% [markdown]
# ### Cut out the extreme values

# %%
sns.violinplot(x='Payment',y='Total',hue='Gender',data=mart,split=True,inner='quartile',bw_method=0.2, cut=0)
# Out:
# <Axes: xlabel='Payment', ylabel='Total'>
