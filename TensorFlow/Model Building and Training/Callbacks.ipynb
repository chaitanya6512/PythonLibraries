# %% [markdown]
# ### Callbacks in TensorFlow:
# - Callbacks are functions or blocks of code that are exceuted at specific stages of the training process.
# - Thet aloow you to interact with the model at various points such as:
#   - At the start and end of an epoch.
#   - Before and after a batch is processed.
#   - At the start and end of training.
# - These interactions can be used to implement custome behavior such as early stopping, learning rate scheduling, saving model check points, logging metrics, and more.

# %% [markdown]
# ### Common TesorFlow Callbacks:
# - TensorFlow provides several built-in callbacks that can be very useful.
# #### 1. Early Stopping:
# - Stops training when a monitored metric has stopped improving.
#   - Function - tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=3)
# #### 2. ModelCheckpoint:
# - Saves the model at specific intervals.
#   - Function - tf.keras.callbacks.ModelCheckpoint(filepath='model.h5', save_best_only=True)
# #### 3. LearningRateScheduler:
# - Schedules changes to the learning rate during training.
#   - Function - tf.keras.callbacks.LearningRateScheduler(scheduler)
# #### 4. TensorBoard:
# - Logs data for visualization un TensorBoard.
#   - Function - tf.keras.callbacks.TensorBoard(log_dir='.logs')

# %% [markdown]
# ### Implementation of Callbacks in TensorFlow:

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten

(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train, x_test = x_train / 255, x_test / 255

model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=3, 
                                                  restore_best_weights=True)
model_checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath='best_model.h5', save_best_only=True, 
                                                      monitor='val_loss')

model.fit(x_train, y_train, epochs=20, validation_split=0.2, 
          callbacks=[early_stopping, model_checkpoint])

test_loss, test_acc = model.evaluate(x_test, y_test)

print(f'Test accuracy:{test_acc}')
# Out:
# Epoch 1/20
# 1494/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8655 - loss: 0.4743
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9179 - loss: 0.2854 - val_accuracy: 0.9514 - val_loss: 0.1649
# Epoch 2/20
# 1492/1500 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9611 - loss: 0.1363
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ...
